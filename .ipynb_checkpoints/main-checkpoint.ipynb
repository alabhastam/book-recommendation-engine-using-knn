# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

# %%
books = pd.read_csv('../data/Books.csv',  encoding='latin-1', on_bad_lines='skip')
users = pd.read_csv('../data/Users.csv',  encoding='latin-1', on_bad_lines='skip')
ratings = pd.read_csv('../data/Ratings.csv',  encoding='latin-1', on_bad_lines='skip')
ratings.columns = ratings.columns.str.strip()
books.columns = books.columns.str.strip()
# Out:
# C:\Users\ali\AppData\Local\Temp\ipykernel_15832\3894335283.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('../data/Books.csv',  encoding='latin-1', on_bad_lines='skip')

# %%
books.info()
users.info()
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249936 entries, 0 to 249935
# Data columns (total 1 columns):
#  #   Column                                                                                         Non-Null Count   Dtype
# ---  ------                                                                                         --------------   -----
#  0   ISBN,Book-Title,Book-Author,Year-Of-Publication,Publisher,Image-URL-S,Image-URL-M,Image-URL-L  249936 non-null  object
# dtypes: object(1)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278698 entries, 0 to 278697
# Data columns (total 1 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   User-ID,Location,Age  278698 non-null  object
# dtypes: object(1)
# memory usage: 2.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   User-ID,ISBN,Book-Rating  1149780 non-null  object
# dtypes: object(1)
# memory usage: 8.8+ MB

# %%
books.describe()
# Out:
#        ISBN,Book-Title,Book-Author,Year-Of-Publication,Publisher,Image-URL-S,Image-URL-M,Image-URL-L
# count                                              249936
# unique                                             249936
# top     0195153448,Classical Mythology,Mark P. O. Morf...
# freq                                                    1

# %%
users.describe()
# Out:
#            User-ID,Location,Age
# count                    278698
# unique                   278698
# top     1,"nyc, new york, usa",
# freq                          1

# %%
ratings.describe()
# Out:
#        User-ID,ISBN,Book-Rating
# count                   1149780
# unique                  1149780
# top         276725,034545104X,0
# freq                          1

# %%
##saving only meaningful rating
ratings = ratings[ratings['Book-Rating'] >0]
print(ratings.columns.tolist())
# Out:
# ['User-ID', 'ISBN', 'Book-Rating']

# %%
# Merge ratings with books
ratings_with_books = ratings.merge(books, on='ISBN')
ratings_with_books.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4   276747  0060517794            9
#
#                                           Book-Title    Book-Author  \
# 0                                   Rites of Passage     Judith Rae
# 1                                     Help!: Level 1  Philip Prowse
# 2  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 3                                    A Painted House   JOHN GRISHAM
# 4                           Little Altars Everywhere  Rebecca Wells
#
#   Year-Of-Publication                   Publisher  \
# 0                2001                      Heinle
# 1                1999  Cambridge University Press
# 2                2001  Cambridge University Press
# 3                2001                   Doubleday
# 4                2003                 HarperTorch
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0155061224.0...
# 1  http://images.amazon.com/images/P/052165615X.0...
# 2  http://images.amazon.com/images/P/0521795028.0...
# 3  http://images.amazon.com/images/P/038550120X.0...
# 4  http://images.amazon.com/images/P/0060517794.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0155061224.0...
# 1  http://images.amazon.com/images/P/052165615X.0...
# 2  http://images.amazon.com/images/P/0521795028.0...
# 3  http://images.amazon.com/images/P/038550120X.0...
# 4  http://images.amazon.com/images/P/0060517794.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0155061224.0...
# 1  http://images.amazon.com/images/P/052165615X.0...
# 2  http://images.amazon.com/images/P/0521795028.0...
# 3  http://images.amazon.com/images/P/038550120X.0...
# 4  http://images.amazon.com/images/P/0060517794.0...

# %%
book_counts = ratings_with_books.groupby('Book-Title').count()['Book-Rating']
popular_books = book_counts[book_counts >= 10].index

user_counts = ratings_with_books.groupby('User-ID').count()['Book-Rating']
active_users = user_counts[user_counts >= 10].index

filtered_df = ratings_with_books[
    (ratings_with_books['Book-Title'].isin(popular_books)) & 
    (ratings_with_books['User-ID'].isin(active_users))
]
filtered_df.head()
# Out:
#     User-ID        ISBN  Book-Rating                           Book-Title  \
# 39   276822  0060096195           10                    The Boy Next Door
# 43   276822  0375821813            9            Hoot (Newbery Honor Book)
# 48   276822  0786817070           10  Artemis Fowl (Artemis Fowl, Book 1)
# 51   276822  1573248533           10              Random Acts of Kindness
# 58   276847  3404148576            8                           Nordermoor
#
#             Book-Author Year-Of-Publication                      Publisher  \
# 39         Meggin Cabot                2002                     Avon Trade
# 43         CARL HIAASEN                2002  Knopf Books for Young Readers
# 48          Eoin Colfer                2002                   Miramax Kids
# 51        Dawna Markova                2002                   Conari Press
# 58  Arnaldur Indridason                2003                    LÃ?ÃÂ¼bbe
#
#                                           Image-URL-S  \
# 39  http://images.amazon.com/images/P/0060096195.0...
# 43  http://images.amazon.com/images/P/0375821813.0...
# 48  http://images.amazon.com/images/P/0786817070.0...
# 51  http://images.amazon.com/images/P/1573248533.0...
# 58  http://images.amazon.com/images/P/3404148576.0...
#
#                                           Image-URL-M  \
# 39  http://images.amazon.com/images/P/0060096195.0...
# 43  http://images.amazon.com/images/P/0375821813.0...
# 48  http://images.amazon.com/images/P/0786817070.0...
# 51  http://images.amazon.com/images/P/1573248533.0...
# 58  http://images.amazon.com/images/P/3404148576.0...
#
#                                           Image-URL-L
# 39  http://images.amazon.com/images/P/0060096195.0...
# 43  http://images.amazon.com/images/P/0375821813.0...
# 48  http://images.amazon.com/images/P/0786817070.0...
# 51  http://images.amazon.com/images/P/1573248533.0...
# 58  http://images.amazon.com/images/P/3404148576.0...

# %%
counts = filtered_df["User-ID"].value_count()
print(counts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15832\846215059.py in ?()
# ----> 1 counts = filtered_df["User-ID"].value_count()
#       2 print(counts)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'
